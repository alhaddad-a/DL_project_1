# %% [markdown]
# #Read From CSV and Write Silver Table

# %% [markdown]
# ###load "cust_info.csv"

# %%
df = spark.read.csv('/Volumes/datalakehouse/bronze/source_systems/source_crm/cust_info.csv', header=True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("datalakehouse.bronze.crm_cust_info")

# %% [markdown]
# ###load "prd_info.csv"

# %%
df = spark.read.csv('/Volumes/datalakehouse/bronze/source_systems/source_crm/prd_info.csv', header=True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("datalakehouse.bronze.crm_prd_info")

# %% [markdown]
# ###load "sales_details.csv"

# %%
df = spark.read.csv('/Volumes/datalakehouse/bronze/source_systems/source_crm/sales_details.csv', header=True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("datalakehouse.bronze.crm_sales_details")

# %% [markdown]
# ###load "CUST_AZ12.csv"

# %%
df = spark.read.csv('/Volumes/datalakehouse/bronze/source_systems/source_erp/CUST_AZ12.csv', header=True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("datalakehouse.bronze.erp_cust_az12")

# %% [markdown]
# ###load "LOC_A101.csv"

# %%
df = spark.read.csv('/Volumes/datalakehouse/bronze/source_systems/source_erp/LOC_A101.csv', header=True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("datalakehouse.bronze.erp_loc_a101")

# %% [markdown]
# ###load "PX_CAT_G1V2.csv"

# %%
df = spark.read.csv('/Volumes/datalakehouse/bronze/source_systems/source_erp/PX_CAT_G1V2.csv', header=True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("datalakehouse.bronze.erp_px_cat_g1v2")
